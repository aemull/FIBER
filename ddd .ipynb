# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
def get_stock_data(stock_code):
    try:
        end_date = datetime.now()
        start_date = end_date - timedelta(days=5*365)
        
        stock = yf.Ticker(stock_code)
        hist = stock.history(start=start_date, end=end_date)
        
        if hist.empty:
            print(f"Tidak ditemukan data untuk {stock_code}")
            return None
        
        # Mengambil hanya kolom Close dan format index
        close_prices = hist['Close']
        
        # Konversi harga ke integer
        close_prices = close_prices.astype(int)
        
        # Format index menjadi hanya tanggal (tanpa waktu)
        close_prices.index = close_prices.index.date
        
        # Hapus .JK dari nama series, hanya ambil kode perusahaan saja
        company_code = stock_code.replace('.JK', '')
        close_prices.name = company_code
        
        return close_prices
    
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def get_multiple_stocks(stock_list):
    all_data = {}
    
    for stock_code in stock_list:
        print(f"Mengambil data {stock_code}...")
        full_stock_code = stock_code + ".JK"
        data = get_stock_data(full_stock_code)
        
        if data is not None:
            all_data[stock_code] = data
    
    if all_data:
        df = pd.DataFrame(all_data)
        df.index.name = 'Date'
        df = df.astype(int)
        return df
    else:
        print("Tidak ada data yang berhasil diambil")
        return None

# %%
def get_status_dataframe(stock_df):
    """
    Membuat dataframe dengan status harga saham terendah
    """
    status_data = []
    
    for column in stock_df.columns:
        try :
            current_price = stock_df[column].iloc[-1]  # Harga terakhir
            all_time_data = stock_df[column]  # Data 5 tahun
            
            # Hitung tanggal untuk periode waktu tertentu
            end_date = datetime.now().date()
            one_year_ago = (datetime.now() - timedelta(days=365)).date()
            three_years_ago = (datetime.now() - timedelta(days=3*365)).date()
            five_years_ago = (datetime.now() - timedelta(days=5*365)).date()
            
            # Filter data berdasarkan periode
            five_year_data = all_time_data[all_time_data.index >= five_years_ago]
            three_year_data = all_time_data[all_time_data.index >= three_years_ago]
            one_year_data = all_time_data[all_time_data.index >= one_year_ago]
            
            # Cek status
            status = None
            
            # 1. Cek apakah harga terendah 5 tahun
            if current_price == five_year_data.min():
                status = "terendah 5 tahun terakhir"
            
            # 2. Cek apakah harga terendah 3 tahun (jika bukan terendah 5 tahun)
            elif status is None and current_price == three_year_data.min():
                status = "terendah 3 tahun terakhir"
            
            # 3. Cek apakah harga terendah 1 tahun (jika bukan terendah 5 atau 3 tahun)
            elif status is None and current_price == one_year_data.min():
                status = "terendah 1 tahun terakhir"
            
            # Hanya tambahkan jika memiliki status
            if status is not None:
                status_data.append({
                    'Kode Perusahaan': column,
                    'Harga Terkini': current_price,
                    'Status': status,
                    'Harga Terendah 1 Tahun': one_year_data.min(),
                    'Harga Terendah 3 Tahun': three_year_data.min(),
                    'Harga Terendah 5 Tahun': five_year_data.min()
                })
        except Exception as e :
            print(e)
    
    # Buat dataframe dari data status
    if status_data:
        status_df = pd.DataFrame(status_data)
        status_df = status_df.set_index('Kode Perusahaan')
        return status_df
    else:
        print("Tidak ada saham yang memenuhi kriteria status")
        return None

# %%
daftar_emitem = pd.read_excel("database/Daftar Saham.xlsx")
stock_list = daftar_emitem["Kode"]

# Ambil data multiple saham
saham_df = get_multiple_stocks(stock_list)

if saham_df is not None:
    print("\nData Harga Saham:")
    print(saham_df.tail())
    print(f"\nShape: {saham_df.shape}")
    
    # Buat dataframe status
    status_df = get_status_dataframe(saham_df)
    
    if status_df is not None:
        print("\nDataFrame Status:")
        print(status_df)
    else:
        print("\nTidak ada saham yang memenuhi kriteria status")
        
    # Tampilkan informasi tambahan
    print(f"\nTanggal data terakhir: {saham_df.index[-1]}")
    print(f"Tanggal 1 tahun lalu: {(datetime.now() - timedelta(days=365)).date()}")
    print(f"Tanggal 3 tahun lalu: {(datetime.now() - timedelta(days=3*365)).date()}")
    print(f"Tanggal 5 tahun lalu: {(datetime.now() - timedelta(days=5*365)).date()}")
# Out:
# Mengambil data AALI...
# Mengambil data ABBA...
# Mengambil data ABDA...
# Mengambil data ABMM...
# Mengambil data ACES...
# Mengambil data ACST...
# Mengambil data ADES...
# Mengambil data ADHI...
# Mengambil data ADMF...
# Mengambil data ADMG...
# Mengambil data ADRO...
# Mengambil data AGII...
# Mengambil data AGRO...
# Mengambil data AGRS...
# Mengambil data AHAP...
# Mengambil data AIMS...
# Mengambil data AISA...
# Mengambil data AKKU...
# Mengambil data AKPI...
# Mengambil data AKRA...
# Mengambil data AKSI...
# Mengambil data ALDO...
# Mengambil data ALKA...
# Mengambil data ALMI...
# Mengambil data ALTO...
# Mengambil data AMAG...
# Mengambil data AMFG...
# Mengambil data AMIN...
# Mengambil data AMRT...
# Mengambil data ANJT...
# Mengambil data ANTM...
# Mengambil data APEX...
# Mengambil data APIC...
# Mengambil data APII...
# Mengambil data APLI...
# Mengambil data APLN...
# Mengambil data ARGO...
# Mengambil data ARII...
# Mengambil data ARNA...
# Mengambil data ARTA...
# Mengambil data ARTI...
# Mengambil data ARTO...
# Mengambil data ASBI...
# Mengambil data ASDM...
# Mengambil data ASGR...
# Mengambil data ASII...
# Mengambil data ASJT...
# Mengambil data ASMI...
# Mengambil data ASRI...
# Mengambil data ASRM...
# Mengambil data ASSA...
# Mengambil data ATIC...
# Mengambil data AUTO...
# Mengambil data BABP...
# Mengambil data BACA...
# Mengambil data BAJA...
# Mengambil data BALI...
# Mengambil data BAPA...
# Mengambil data BATA...
# Mengambil data BAYU...
# Mengambil data BBCA...
# Mengambil data BBHI...
# Mengambil data BBKP...
# Mengambil data BBLD...
# Mengambil data BBMD...
# Mengambil data BBNI...
# Mengambil data BBRI...
# Mengambil data BBRM...
# Mengambil data BBTN...
# Mengambil data BBYB...
# Mengambil data BCAP...
# Mengambil data BCIC...
# Mengambil data BCIP...
# Mengambil data BDMN...
# Mengambil data BEKS...
# Mengambil data BEST...
# Mengambil data BFIN...
# Mengambil data BGTG...
# Mengambil data BHIT...
# Mengambil data BIKA...
# Mengambil data BIMA...
# Mengambil data BINA...
# Mengambil data BIPI...
# Mengambil data BIPP...
# Mengambil data BIRD...
# Mengambil data BISI...
# Mengambil data BJBR...
# Mengambil data BJTM...
# Mengambil data BKDP...
# Mengambil data BKSL...
# Mengambil data BKSW...
# Mengambil data BLTA...
# Mengambil data BLTZ...
# Mengambil data BMAS...
# Mengambil data BMRI...
# Mengambil data BMSR...
# Mengambil data BMTR...
# Mengambil data BNBA...
# Mengambil data BNBR...
# Mengambil data BNGA...
# Mengambil data BNII...
# Mengambil data BNLI...
# Mengambil data BOLT...
# Mengambil data BPFI...
# Mengambil data BPII...
# Mengambil data BRAM...
# Mengambil data BRMS...
# Mengambil data BRNA...
# Mengambil data BRPT...
# Mengambil data BSDE...
# Mengambil data BSIM...
# Mengambil data BSSR...
# Mengambil data BSWD...
# Mengambil data BTEK...
# Mengambil data BTEL...
# Mengambil data BTON...
# Mengambil data BTPN...
# Mengambil data BUDI...
# Mengambil data BUKK...
# Mengambil data BULL...
# Mengambil data BUMI...
# Mengambil data BUVA...
# Mengambil data BVIC...
# Mengambil data BWPT...
# Mengambil data BYAN...
# Mengambil data CANI...
# Mengambil data CASS...
# Mengambil data CEKA...
# Mengambil data CENT...
# Mengambil data CFIN...
# Mengambil data CINT...
# Mengambil data CITA...
# Mengambil data CLPI...
# Mengambil data CMNP...
# Mengambil data CMPP...
# Mengambil data CNKO...
# Mengambil data CNTX...
# Mengambil data COWL...
# Mengambil data CPIN...
# Mengambil data CPRO...
# Mengambil data CSAP...
# Mengambil data CTBN...
# Mengambil data CTRA...
# Mengambil data CTTH...
# Mengambil data DART...
# Mengambil data DEFI...
# Mengambil data DEWA...
# Mengambil data DGIK...
# Mengambil data DILD...
# Mengambil data DKFT...
# Mengambil data DLTA...
# Mengambil data DMAS...
# Mengambil data DNAR...
# Mengambil data DNET...
# Mengambil data DOID...
# Mengambil data DPNS...
# Mengambil data DSFI...
# Mengambil data DSNG...
# Mengambil data DSSA...
# Mengambil data DUTI...
# Mengambil data DVLA...
# Mengambil data DYAN...
# Mengambil data ECII...
# Mengambil data EKAD...
# Mengambil data ELSA...
# Mengambil data ELTY...
# Mengambil data EMDE...
# Mengambil data EMTK...
# Mengambil data ENRG...
# Mengambil data EPMT...
# Mengambil data ERAA...
# Mengambil data ERTX...
# Mengambil data ESSA...
# Mengambil data ESTI...
# Mengambil data ETWA...
# Mengambil data EXCL...
# Mengambil data FAST...
# Mengambil data FASW...
# Mengambil data FISH...
# Mengambil data FMII...
# Mengambil data FORU...
# Mengambil data FPNI...
# Mengambil data GAMA...
# Mengambil data GDST...
# Mengambil data GDYR...
# Mengambil data GEMA...
# Mengambil data GEMS...
# Mengambil data GGRM...
# Mengambil data GIAA...
# Mengambil data GJTL...
# Mengambil data GLOB...
# Mengambil data GMTD...
# Mengambil data GOLD...
# Mengambil data GOLL...
# Mengambil data GPRA...
# Mengambil data GSMF...
# Mengambil data GTBO...
# Mengambil data GWSA...
# Mengambil data GZCO...
# Mengambil data HADE...
# Mengambil data HDFA...
# Mengambil data HDTX...
# Mengambil data HERO...
# Mengambil data HEXA...
# Mengambil data HITS...
# Mengambil data HMSP...
# Mengambil data HOME...
# Mengambil data HOTL...
# Mengambil data HRUM...
# Mengambil data IATA...
# Mengambil data IBFN...
# Mengambil data IBST...
# Mengambil data ICBP...
# Mengambil data ICON...
# Mengambil data IGAR...
# Mengambil data IIKP...
# Mengambil data IKAI...
# Mengambil data IKBI...
# Mengambil data IMAS...
# Mengambil data IMJS...
# Mengambil data IMPC...
# Mengambil data INAF...
# Mengambil data INAI...
# Mengambil data INCI...
# Mengambil data INCO...
# Mengambil data INDF...
# Mengambil data INDR...
# Mengambil data INDS...
# Mengambil data INDX...
# Mengambil data INDY...
# Mengambil data INKP...
# Mengambil data INPC...
# Mengambil data INPP...
# Mengambil data INRU...
# Mengambil data INTA...
# Mengambil data INTD...
# Mengambil data INTP...
# Mengambil data IPOL...
# Mengambil data ISAT...
# Mengambil data ISSP...
# Mengambil data ITMA...
# Mengambil data ITMG...
# Mengambil data JAWA...
# Mengambil data JECC...
# Mengambil data JIHD...
# Mengambil data JKON...
# Mengambil data JKSW...
# Mengambil data JPFA...
# Mengambil data JRPT...
# Mengambil data JSMR...
# Mengambil data JSPT...
# Mengambil data JTPE...
# Mengambil data KAEF...
# Mengambil data KARW...
# Mengambil data KBLI...
# Mengambil data KBLM...
# Mengambil data KBLV...
# Mengambil data KBRI...
# Mengambil data KDSI...
# Mengambil data KIAS...
# Mengambil data KICI...
# Mengambil data KIJA...
# Mengambil data KKGI...
# Mengambil data KLBF...
# Mengambil data KOBX...
# Mengambil data KOIN...
# Mengambil data KONI...
# Mengambil data KOPI...
# Mengambil data KPIG...
# Mengambil data KRAH...
# Mengambil data KRAS...
# Mengambil data KREN...
# Mengambil data LAPD...
# Mengambil data LCGP...
# Mengambil data LEAD...
# Mengambil data LINK...
# Mengambil data LION...
# Mengambil data LMAS...
# Mengambil data LMPI...
# Mengambil data LMSH...
# Mengambil data LPCK...
# Mengambil data LPGI...
# Mengambil data LPIN...
# Mengambil data LPKR...
# Mengambil data LPLI...
# Mengambil data LPPF...
# Mengambil data LPPS...
# Mengambil data LRNA...
# Mengambil data LSIP...
# Mengambil data LTLS...
# Mengambil data MAGP...
# Mengambil data MAIN...
# Mengambil data MAMI...
# Mengambil data MAPI...
# Mengambil data MASA...
# Mengambil data MAYA...
# Mengambil data MBAP...
# Mengambil data MBSS...
# Mengambil data MBTO...
# Mengambil data MCOR...
# Mengambil data MDIA...
# Mengambil data MDKA...
# Mengambil data MDLN...
# Mengambil data MDRN...
# Mengambil data MEDC...
# Mengambil data MEGA...
# Mengambil data MERK...
# Mengambil data META...
# Mengambil data MFIN...
# Mengambil data MFMI...
# Mengambil data MGNA...
# Mengambil data MICE...
# Mengambil data MIDI...
# Mengambil data MIKA...
# Mengambil data MIRA...
# Mengambil data MITI...
# Mengambil data MKPI...
# Mengambil data MLBI...
# Mengambil data MLIA...
# Mengambil data MLPL...
# Mengambil data MLPT...
# Mengambil data MMLP...
# Mengambil data MNCN...
# Mengambil data MPMX...
# Mengambil data MPPA...
# Mengambil data MRAT...
# Mengambil data MREI...
# Mengambil data MSKY...
# Mengambil data MTDL...
# Mengambil data MTFN...
# Mengambil data MTLA...
# Mengambil data MTSM...
# Mengambil data MYOH...
# Mengambil data MYOR...
# Mengambil data MYRX...
# Mengambil data MYTX...
# Mengambil data NELY...
# Mengambil data NIKL...
# Mengambil data NIPS...
# Mengambil data NIRO...
# Mengambil data NISP...
# Mengambil data NOBU...
# Mengambil data NRCA...
# Mengambil data OCAP...
# Mengambil data OKAS...
# Mengambil data OMRE...
# Mengambil data PADI...
# Mengambil data PALM...
# Mengambil data PANR...
# Mengambil data PANS...
# Mengambil data PBRX...
# Mengambil data PDES...
# Mengambil data PEGE...
# Mengambil data PGAS...
# Mengambil data PGLI...
# Mengambil data PICO...
# Mengambil data PJAA...
# Mengambil data PKPK...
# Mengambil data PLAS...
# Mengambil data PLIN...
# Mengambil data PNBN...
# Mengambil data PNBS...
# Mengambil data PNIN...
# Mengambil data PNLF...
# Mengambil data PNSE...
# Mengambil data POLY...
# Mengambil data POOL...
# Mengambil data PPRO...
# Mengambil data PRAS...
# Mengambil data PSAB...
# Mengambil data PSDN...
# Mengambil data PSKT...
# Mengambil data PTBA...
# Mengambil data PTIS...
# Mengambil data PTPP...
# Mengambil data PTRO...
# Mengambil data PTSN...
# Mengambil data PTSP...
# Mengambil data PUDP...
# Mengambil data PWON...
# Mengambil data PYFA...
# Mengambil data RAJA...
# Mengambil data RALS...
# Mengambil data RANC...
# Mengambil data RBMS...
# Mengambil data RDTX...
# Mengambil data RELI...
# Mengambil data RICY...
# Mengambil data RIGS...
# Mengambil data RIMO...
# Mengambil data RODA...
# Mengambil data ROTI...
# Mengambil data RUIS...
# Mengambil data SAFE...
# Mengambil data SAME...
# Mengambil data SCCO...
# Mengambil data SCMA...
# Mengambil data SCPI...
# Mengambil data SDMU...
# Mengambil data SDPC...
# Mengambil data SDRA...
# Mengambil data SGRO...
# Mengambil data SHID...
# Mengambil data SIDO...
# Mengambil data SILO...
# Mengambil data SIMA...
# Mengambil data SIMP...
# Mengambil data SIPD...
# Mengambil data SKBM...
# Mengambil data SKLT...
# Mengambil data SKYB...
# Mengambil data SMAR...
# Mengambil data SMBR...
# Mengambil data SMCB...
# Mengambil data SMDM...
# Mengambil data SMDR...
# Mengambil data SMGR...
# Mengambil data SMMA...
# Mengambil data SMMT...
# Mengambil data SMRA...
# Mengambil data SMRU...
# Mengambil data SMSM...
# Mengambil data SOCI...
# Mengambil data SONA...
# Mengambil data SPMA...
# Mengambil data SQMI...
# Mengambil data SRAJ...
# Mengambil data SRIL...
# Mengambil data SRSN...
# Mengambil data SRTG...
# Mengambil data SSIA...
# Mengambil data SSMS...
# Mengambil data SSTM...
# Mengambil data STAR...
# Mengambil data STTP...
# Mengambil data SUGI...
# Mengambil data SULI...
# Mengambil data SUPR...
# Mengambil data TALF...
# Mengambil data TARA...
# Mengambil data TAXI...
# Mengambil data TBIG...
# Mengambil data TBLA...
# Mengambil data TBMS...
# Mengambil data TCID...
# Mengambil data TELE...
# Mengambil data TFCO...
# Mengambil data TGKA...
# Mengambil data TIFA...
# Mengambil data TINS...
# Mengambil data TIRA...
# Mengambil data TIRT...
# Mengambil data TKIM...
# Mengambil data TLKM...
# Mengambil data TMAS...
# Mengambil data TMPO...
# Mengambil data TOBA...
# Mengambil data TOTL...
# Mengambil data TOTO...
# Mengambil data TOWR...
# Mengambil data TPIA...
# Mengambil data TPMA...
# Mengambil data TRAM...
# Mengambil data TRIL...
# Mengambil data TRIM...
# Mengambil data TRIO...
# Mengambil data TRIS...
# Mengambil data TRST...
# Mengambil data TRUS...
# Mengambil data TSPC...
# Mengambil data ULTJ...
# Mengambil data UNIC...
# Mengambil data UNIT...
# Mengambil data UNSP...
# Mengambil data UNTR...
# Mengambil data UNVR...
# Mengambil data VICO...
# Mengambil data VINS...
# Mengambil data VIVA...
# Mengambil data VOKS...
# Mengambil data VRNA...
# Mengambil data WAPO...
# Mengambil data WEHA...
# Mengambil data WICO...
# Mengambil data WIIM...
# Mengambil data WIKA...
# Mengambil data WINS...
# Mengambil data WOMF...
# Mengambil data WSKT...
# Mengambil data WTON...
# Mengambil data YPAS...
# Mengambil data YULE...
# Mengambil data ZBRA...
# Mengambil data SHIP...
# Mengambil data CASA...
# Mengambil data DAYA...
# Mengambil data DPUM...
# Mengambil data IDPR...
# Mengambil data JGLE...
# Mengambil data KINO...
# Mengambil data MARI...
# Mengambil data MKNT...
# Mengambil data MTRA...
# Mengambil data OASA...
# Mengambil data POWR...
# Mengambil data INCF...
# Mengambil data WSBP...
# Mengambil data PBSA...
# Mengambil data PRDA...
# Mengambil data BOGA...
# Mengambil data BRIS...
# Mengambil data PORT...
# Mengambil data CARS...
# Mengambil data MINA...
# Mengambil data FORZ...
# Mengambil data CLEO...
# Mengambil data TAMU...
# Mengambil data CSIS...
# Mengambil data TGRA...
# Mengambil data FIRE...
# Mengambil data TOPS...
# Mengambil data KMTR...
# Mengambil data ARMY...
# Mengambil data MAPB...
# Mengambil data WOOD...
# Mengambil data HRTA...
# Mengambil data MABA...
# Mengambil data HOKI...
# Mengambil data MPOW...
# Mengambil data MARK...
# Mengambil data NASA...
# Mengambil data MDKI...
# Mengambil data BELL...
# Mengambil data KIOS...
# Mengambil data GMFI...
# Mengambil data MTWI...
# Mengambil data ZINC...
# Mengambil data MCAS...
# Mengambil data PPRE...
# Mengambil data WEGE...
# Mengambil data PSSI...
# Mengambil data MORA...
# Mengambil data DWGL...
# Mengambil data PBID...
# Mengambil data JMAS...
# Mengambil data CAMP...
# Mengambil data IPCM...
# Mengambil data PCAR...
# Mengambil data LCKM...
# Mengambil data BOSS...
# Mengambil data HELI...
# Mengambil data JSKY...
# Mengambil data INPS...
# Mengambil data GHON...
# Mengambil data TDPM...
# Mengambil data DFAM...
# Mengambil data NICK...
# Mengambil data BTPS...
# Mengambil data SPTO...
# Mengambil data PRIM...
# Mengambil data HEAL...
# Mengambil data TRUK...
# Mengambil data PZZA...
# Mengambil data TUGU...
# Mengambil data MSIN...
# Mengambil data SWAT...
# Mengambil data KPAL...
# Mengambil data TNCA...
# Mengambil data MAPA...
# Mengambil data TCPI...
# Mengambil data IPCC...
# Mengambil data RISE...
# Mengambil data BPTR...
# Mengambil data POLL...
# Mengambil data NFCX...
# Mengambil data MGRO...
# Mengambil data NUSA...
# Mengambil data FILM...
# Mengambil data ANDI...
# Mengambil data LAND...
# Mengambil data MOLI...
# Mengambil data PANI...
# Mengambil data DIGI...
# Mengambil data CITY...
# Mengambil data SAPX...
# Mengambil data KPAS...
# Mengambil data SURE...
# Mengambil data HKMU...
# Mengambil data MPRO...
# Mengambil data DUCK...
# Mengambil data GOOD...
# Mengambil data SKRN...
# Mengambil data YELO...
# Mengambil data CAKK...
# Mengambil data SATU...
# Mengambil data ZONE...
# Mengambil data PEHA...
# Mengambil data FOOD...
# Mengambil data BEEF...
# Mengambil data POLI...
# Mengambil data CLAY...
# Mengambil data NATO...
# Mengambil data JAYA...
# Mengambil data COCO...
# Mengambil data MTPS...
# Mengambil data CPRI...
# Mengambil data HRME...
# Mengambil data POSA...
# Mengambil data JAST...
# Mengambil data FITT...
# Mengambil data BOLA...
# Mengambil data CCSI...
# Mengambil data SFAN...
# Mengambil data POLU...
# Mengambil data KJEN...
# Mengambil data KAYU...
# Mengambil data ITIC...
# Mengambil data PAMG...
# Mengambil data IPTV...
# Mengambil data BLUE...
# Mengambil data ENVY...
# Mengambil data EAST...
# Mengambil data LIFE...
# Mengambil data FUJI...
# Mengambil data KOTA...
# Mengambil data INOV...
# Mengambil data ARKA...
# Mengambil data SMKL...
# Mengambil data HDIT...
# Mengambil data KEEN...
# Mengambil data BAPI...
# Mengambil data TFAS...
# Mengambil data GGRP...
# Mengambil data OPMS...
# Mengambil data NZIA...
# Mengambil data SLIS...
# Mengambil data PURE...
# Mengambil data IRRA...
# Mengambil data DMMX...
# Mengambil data SINI...
# Mengambil data WOWS...
# Mengambil data ESIP...
# Mengambil data TEBE...
# Mengambil data KEJU...
# Mengambil data PSGO...
# Mengambil data AGAR...
# Mengambil data IFSH...
# Mengambil data REAL...
# Mengambil data IFII...
# Mengambil data PMJS...
# Mengambil data UCID...
# Mengambil data GLVA...
# Mengambil data PGJO...
# Mengambil data AMAR...
# Mengambil data CSRA...
# Mengambil data INDO...
# Mengambil data AMOR...
# Mengambil data TRIN...
# Mengambil data DMND...
# Mengambil data PURA...
# Mengambil data PTPW...
# Mengambil data TAMA...
# Mengambil data IKAN...
# Mengambil data AYLS...
# Mengambil data DADA...
# Mengambil data ASPI...
# Mengambil data ESTA...
# Mengambil data BESS...
# Mengambil data CSMI...
# Mengambil data BBSS...
# Mengambil data BHAT...
# Mengambil data CASH...
# Mengambil data TECH...
# Mengambil data EPAC...
# Mengambil data UANG...
# Mengambil data PGUN...
# Mengambil data SOFA...
# Mengambil data PPGL...
# Mengambil data TOYS...
# Mengambil data SGER...
# Mengambil data TRJA...
# Mengambil data PNGO...
# Mengambil data SCNP...
# Mengambil data BBSI...
# Mengambil data KMDS...
# Mengambil data PURI...
# Mengambil data SOHO...
# Mengambil data HOMI...
# Mengambil data ROCK...
# Mengambil data ENZO...
# Mengambil data PLAN...
# Mengambil data PTDU...
# Mengambil data ATAP...
# Mengambil data VICI...
# Mengambil data PMMP...
# Mengambil data WIFI...
# Mengambil data FAPA...
# Mengambil data DCII...
# Mengambil data KETR...
# Mengambil data DGNS...
# Mengambil data UFOE...
# Mengambil data BANK...
# Mengambil data WMUU...
# Mengambil data EDGE...
# Mengambil data UNIQ...
# Mengambil data BEBS...
# Mengambil data SNLK...
# Mengambil data ZYRX...
# Mengambil data LFLO...
# Mengambil data FIMP...
# Mengambil data TAPG...
# Mengambil data NPGF...
# Mengambil data LUCY...
# Mengambil data ADCP...
# Mengambil data HOPE...
# Mengambil data MGLV...
# Mengambil data TRUE...
# Mengambil data LABA...
# Mengambil data ARCI...
# Mengambil data IPAC...
# Mengambil data MASB...
# Mengambil data BMHS...
# Mengambil data FLMC...
# Mengambil data NICL...
# Mengambil data UVCR...
# Mengambil data BUKA...
# Mengambil data HAIS...
# Mengambil data OILS...
# Mengambil data GPSO...
# Mengambil data MCOL...
# Mengambil data RSGK...
# Mengambil data RUNS...
# Mengambil data SBMA...
# Mengambil data CMNT...
# Mengambil data GTSI...
# Mengambil data IDEA...
# Mengambil data KUAS...
# Mengambil data BOBA...
# Mengambil data MTEL...
# Mengambil data DEPO...
# Mengambil data BINO...
# Mengambil data CMRY...
# Mengambil data WGSH...
# Mengambil data TAYS...
# Mengambil data WMPP...
# Mengambil data RMKE...
# Mengambil data OBMD...
# Mengambil data AVIA...
# Mengambil data IPPE...
# Mengambil data NASI...
# Mengambil data BSML...
# Mengambil data DRMA...
# Mengambil data ADMR...
# Mengambil data SEMA...
# Mengambil data ASLC...
# Mengambil data NETV...
# Mengambil data BAUT...
# Mengambil data ENAK...
# Mengambil data NTBK...
# Mengambil data SMKM...
# Mengambil data STAA...
# Mengambil data NANO...
# Mengambil data BIKE...
# Mengambil data WIRG...
# Mengambil data SICO...
# Mengambil data GOTO...
# Mengambil data TLDN...
# Mengambil data MTMH...
# Mengambil data WINR...
# Mengambil data IBOS...
# Mengambil data OLIV...
# Mengambil data ASHA...
# Mengambil data SWID...
# Mengambil data TRGU...
# Mengambil data ARKO...
# Mengambil data CHEM...
# Mengambil data DEWI...
# Mengambil data AXIO...
# Mengambil data KRYA...
# Mengambil data HATM...
# Mengambil data RCCC...
# Mengambil data GULA...
# Mengambil data JARR...
# Mengambil data AMMS...
# Mengambil data BUAH...
# Mengambil data CRAB...
# Mengambil data MEDS...
# Mengambil data COAL...
# Mengambil data PRAY...
# Mengambil data CBUT...
# Mengambil data BELI...
# Mengambil data MKTR...
# Mengambil data OMED...
# Mengambil data BSBK...
# Mengambil data PDPP...
# Mengambil data KDTN...
# Mengambil data ZATA...
# Mengambil data NINE...
# Mengambil data MMIX...
# Mengambil data PADA...
# Mengambil data ISAP...
# Mengambil data VTNY...
# Mengambil data SOUL...
# Mengambil data ELIT...
# Mengambil data BEER...
# Mengambil data CBPE...
# Mengambil data SUNI...
# Mengambil data CBRE...
# Mengambil data WINE...
# Mengambil data BMBL...
# Mengambil data PEVE...
# Mengambil data LAJU...
# Mengambil data FWCT...
# Mengambil data NAYZ...
# Mengambil data IRSX...
# Mengambil data PACK...
# Mengambil data VAST...
# Mengambil data CHIP...
# Mengambil data HALO...
# Mengambil data KING...
# Mengambil data PGEO...
# Mengambil data FUTR...
# Mengambil data HILL...
# Mengambil data BDKR...
# Mengambil data PTMP...
# Mengambil data SAGE...
# Mengambil data TRON...
# Mengambil data CUAN...
# Mengambil data NSSS...
# Mengambil data GTRA...
# Mengambil data HAJJ...
# Mengambil data PIPA...
# Mengambil data NCKL...
# Mengambil data MENN...
# Mengambil data AWAN...
# Mengambil data MBMA...
# Mengambil data RAAM...
# Mengambil data DOOH...
# Mengambil data JATI...
# Mengambil data TYRE...
# Mengambil data MPXL...
# Mengambil data SMIL...
# Mengambil data KLAS...
# Mengambil data MAXI...
# Mengambil data VKTR...
# Mengambil data RELF...
# Mengambil data AMMN...
# Mengambil data CRSN...
# Mengambil data GRPM...
# Mengambil data WIDI...
# Mengambil data TGUK...
# Mengambil data INET...
# Mengambil data MAHA...
# Mengambil data RMKO...
# Mengambil data CNMA...
# Mengambil data FOLK...
# Mengambil data HBAT...
# Mengambil data GRIA...
# Mengambil data PPRI...
# Mengambil data ERAL...
# Mengambil data CYBR...
# Mengambil data MUTU...
# Mengambil data LMAX...
# Mengambil data HUMI...
# Mengambil data MSIE...
# Mengambil data RSCH...
# Mengambil data BABY...
# Mengambil data AEGS...
# Mengambil data IOTF...
# Mengambil data KOCI...
# Mengambil data PTPS...
# Mengambil data BREN...
# Mengambil data STRK...
# Mengambil data KOKA...
# Mengambil data LOPI...
# Mengambil data UDNG...
# Mengambil data RGAS...
# Mengambil data MSTI...
# Mengambil data IKPM...
# Mengambil data AYAM...
# Mengambil data SURI...
# Mengambil data ASLI...
# Mengambil data CGAS...
# Mengambil data NICE...
# Mengambil data MSJA...
# Mengambil data SMLE...
# Mengambil data ACRO...
# Mengambil data MANG...
# Mengambil data GRPH...
# Mengambil data SMGA...
# Mengambil data UNTD...
# Mengambil data TOSK...
# Mengambil data MPIX...
# Mengambil data ALII...
# Mengambil data MKAP...
# Mengambil data MEJA...
# Mengambil data LIVE...
# Mengambil data HYGN...
# Mengambil data BAIK...
# Mengambil data VISI...
# Mengambil data AREA...
# Mengambil data MHKI...
# Mengambil data ATLA...
# Mengambil data DATA...
# Mengambil data SOLA...
# Mengambil data BATR...
# Mengambil data SPRE...
# Mengambil data PART...
# Mengambil data GOLF...
# Mengambil data ISEA...
# Mengambil data BLES...
# Mengambil data GUNA...
# Mengambil data LABS...
# Mengambil data DOSS...
# Mengambil data NEST...
# Mengambil data PTMR...
# Mengambil data VERN...
# Mengambil data DAAZ...
# Mengambil data BOAT...
# Mengambil data NAIK...
# Mengambil data AADI...
# Mengambil data MDIY...
# Mengambil data KSIX...
# Mengambil data RATU...
# Mengambil data YOII...
# Mengambil data HGII...
# Mengambil data BRRC...
# Mengambil data DGWG...
# Mengambil data CBDK...
# Mengambil data OBAT...
# Mengambil data MINE...
# Mengambil data KAQI...
# Mengambil data YUPI...
# Mengambil data FORE...
# Mengambil data MDLA...
# Mengambil data SOSS...
# Mengambil data DEAL...
# Mengambil data POLA...
# Mengambil data DIVA...
# Mengambil data LUCK...
# Mengambil data URBN...
# Mengambil data SOTS...
# Mengambil data AMAN...
# Mengambil data CARE...
# Mengambil data SAMF...
# Mengambil data SBAT...
# Mengambil data KBAG...
# Mengambil data CBMF...
# Mengambil data RONY...
# Mengambil data RAFI...
# Mengambil data KKES...
# Mengambil data ELPI...
# Mengambil data EURO...
# Mengambil data KLIN...
# Mengambil data TOOL...
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[9], line 5
#       2 stock_list = daftar_emitem["Kode"]
#       4 # Ambil data multiple saham
# ----> 5 saham_df = get_multiple_stocks(stock_list)
#       7 if saham_df is not None:
#       8     print("\nData Harga Saham:")
#
# Cell In[4], line 15, in get_multiple_stocks(stock_list)
#      13     df = pd.DataFrame(all_data)
#      14     df.index.name = 'Date'
# ---> 15     df = df.astype(int)
#      16     return df
#      17 else:
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\Tefa 7\Documents\Datascrape\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
