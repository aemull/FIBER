# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

Daftar_Saham = pd.read_excel("database/Daftar Saham.xlsx")
kode_perusahaan = Daftar_Saham['Kode']
kode_perusahaan1 = kode_perusahaan + ".JK"

# %%
ticker = yf.Tickers(kode_perusahaan1.to_list())

# %%
data_saham_emitem = ticker.download(period="10y")['Close'].round(2)
data_saham_emitem.columns = data_saham_emitem.columns.str.replace(r"\.JK$", "", regex=True)
# Out:
# [*********************100%***********************]  955 of 955 completed
# Ticker      AADI      AALI   ABBA     ABDA    ABMM    ACES  ACRO     ACST  \
# Date
# 2015-09-22   NaN  12764.46  39.73  6297.17  2006.4  387.46   NaN  1960.26
# 2015-09-23   NaN  12782.29  41.32  6297.17  2006.4  387.46   NaN  1933.63
# 2015-09-25   NaN  12800.11  48.47  6297.17  2006.4  387.46   NaN  1933.63
# 2015-09-28   NaN  12693.15  43.70  6297.17  2006.4  383.70   NaN  1933.63
# 2015-09-29   NaN  12907.08  40.52  6297.17  2006.4  387.46   NaN  1936.05
#
# Ticker      ADCP    ADES  ...  YELO  YOII   YPAS   YULE  YUPI  ZATA   ZBRA  \
# Date                      ...
# 2015-09-22   NaN  1100.0  ...   NaN   NaN  600.0  76.46   NaN   NaN  82.70
# 2015-09-23   NaN  1100.0  ...   NaN   NaN  600.0  76.46   NaN   NaN  82.70
# 2015-09-25   NaN  1055.0  ...   NaN   NaN  600.0  76.46   NaN   NaN  79.43
# 2015-09-28   NaN  1055.0  ...   NaN   NaN  600.0  79.40   NaN   NaN  77.79
# 2015-09-29   NaN  1050.0  ...   NaN   NaN  600.0  79.40   NaN   NaN  78.61
#
# Ticker      ZINC  ZONE  ZYRX
# Date
# 2015-09-22   NaN   NaN   NaN
# 2015-09-23   NaN   NaN   NaN
# 2015-09-25   NaN   NaN   NaN
# 2015-09-28   NaN   NaN   NaN
# 2015-09-29   NaN   NaN   NaN
#
# [5 rows x 955 columns]

# %%
tanggal_paling_baru = data_saham_emitem.index.max()
tanggal_paling_lama5 = tanggal_paling_baru - pd.DateOffset(years=5)
tanggal_paling_lama3 = tanggal_paling_baru - pd.DateOffset(years=3)
tanggal_paling_lama1 = tanggal_paling_baru - pd.DateOffset(years=1)

# %%
harga_sekarang = (data_saham_emitem[data_saham_emitem.index == tanggal_paling_baru]).T
harga_sekarang.columns = ["Now"]
harga_sekarang
# Out:
#            Now
# Ticker
# AADI    7075.0
# AALI    7775.0
# ABBA      68.0
# ABDA    2970.0
# ABMM    2890.0
# ...        ...
# ZATA      50.0
# ZBRA      50.0
# ZINC      45.0
# ZONE     755.0
# ZYRX     147.0
#
# [955 rows x 1 columns]

# %%
data_1year = data_saham_emitem[data_saham_emitem.index >= tanggal_paling_lama1]
daftar_perusahaan_1thn = data_1year[data_1year.index.year == tanggal_paling_lama1.year].dropna(axis=1, how="all")
daftar_perusahaan_1thn = daftar_perusahaan_1thn.columns.to_list()
data_1year = data_1year[daftar_perusahaan_1thn]
data_1year
# Out:
# Ticker        AADI     AALI  ABBA    ABDA     ABMM    ACES   ACRO   ACST  \
# Date
# 2024-09-23     NaN  6437.88  39.0  4050.0  4186.46  840.81  63.56  119.0
# 2024-09-24     NaN  6437.88  38.0  4050.0  4176.93  822.13  61.99  121.0
# 2024-09-25     NaN  6437.88  38.0  4050.0  4100.64  812.78  62.77  118.0
# 2024-09-26     NaN  6485.75  38.0  4060.0  4138.78  845.48  62.77  117.0
# 2024-09-27     NaN  6413.95  38.0  4060.0  4348.58  854.82  62.77  115.0
# ...            ...      ...   ...     ...      ...     ...    ...    ...
# 2025-09-16  6975.0  7750.00  52.0  2970.0  2930.00  436.00  86.00  134.0
# 2025-09-17  7100.0  7900.00  57.0  2970.0  2900.00  446.00  85.00  141.0
# 2025-09-18  6975.0  8000.00  62.0  2970.0  2890.00  436.00  85.00  138.0
# 2025-09-19  7100.0  7850.00  62.0  2970.0  2890.00  432.00  85.00  136.0
# 2025-09-22  7075.0  7775.00  68.0  2970.0  2890.00  426.00  85.00  135.0
#
# Ticker      ADCP     ADES  ...   WSKT    WTON  YELO   YPAS     YULE   ZATA  \
# Date                       ...
# 2024-09-23  51.0  10225.0  ...  202.0  106.08  18.0  274.0  2502.51   9.95
# 2024-09-24  50.0  10450.0  ...  202.0  109.05  18.0  274.0  2502.51   8.95
# 2024-09-25  51.0  10450.0  ...  202.0  107.07  18.0  274.0  2502.51   9.95
# 2024-09-26  50.0  10375.0  ...  202.0  107.07  17.0  272.0  2492.54   9.95
# 2024-09-27  50.0  10300.0  ...  202.0  106.08  16.0  274.0  2492.54   9.95
# ...          ...      ...  ...    ...     ...   ...    ...      ...    ...
# 2025-09-16  65.0  13125.0  ...  202.0  106.00  66.0  354.0  2700.00  36.00
# 2025-09-17  64.0  13150.0  ...  202.0  108.00  70.0  354.0  2710.00  39.00
# 2025-09-18  63.0  13075.0  ...  202.0  105.00  65.0  354.0  2710.00  42.00
# 2025-09-19  60.0  13350.0  ...  202.0  105.00  65.0  354.0  2690.00  46.00
# 2025-09-22  61.0  13300.0  ...  202.0  103.00  70.0  354.0  2680.00  50.00
#
# Ticker       ZBRA  ZINC   ZONE    ZYRX
# Date
# 2024-09-23  137.0  15.0  905.0  145.28
# 2024-09-24  142.0  16.0  905.0  145.28
# 2024-09-25  136.0  16.0  905.0  144.29
# 2024-09-26  120.0  16.0  890.0  145.28
# 2024-09-27  117.0  16.0  875.0  145.28
# ...           ...   ...    ...     ...
# 2025-09-16   50.0  39.0  760.0  149.00
# 2025-09-17   50.0  42.0  755.0  149.00
# 2025-09-18   50.0  46.0  755.0  145.00
# 2025-09-19   50.0  50.0  755.0  145.00
# 2025-09-22   50.0  45.0  755.0  147.00
#
# [236 rows x 942 columns]

# %%
data_3year = data_saham_emitem[data_saham_emitem.index >= tanggal_paling_lama3]
daftar_perusahaan_3thn = data_3year[data_3year.index.year == tanggal_paling_lama3.year].dropna(axis=1, how="all")
daftar_perusahaan_3thn = daftar_perusahaan_3thn.columns.to_list()
data_3year = data_3year[daftar_perusahaan_3thn]
data_3year
# Out:
# Ticker         AALI   ABBA    ABDA     ABMM    ACES   ACST  ADCP     ADES  \
# Date
# 2022-09-22  7851.36  212.0  5975.0  3710.90  538.82  208.0  78.0   7300.0
# 2022-09-23  7807.50  232.0  6025.0  3602.43  534.54  210.0  78.0   7200.0
# 2022-09-26  7763.63  224.0  6025.0  3393.26  555.92  196.0  77.0   7275.0
# 2022-09-27  7675.91  226.0  6025.0  3462.99  555.92  193.0  77.0   7150.0
# 2022-09-28  7544.32  232.0  6025.0  3308.04  543.09  187.0  77.0   7000.0
# ...             ...    ...     ...      ...     ...    ...   ...      ...
# 2025-09-16  7750.00   52.0  2970.0  2930.00  436.00  134.0  65.0  13125.0
# 2025-09-17  7900.00   57.0  2970.0  2900.00  446.00  141.0  64.0  13150.0
# 2025-09-18  8000.00   62.0  2970.0  2890.00  436.00  138.0  63.0  13075.0
# 2025-09-19  7850.00   62.0  2970.0  2890.00  432.00  136.0  60.0  13350.0
# 2025-09-22  7775.00   68.0  2970.0  2890.00  426.00  135.0  61.0  13300.0
#
# Ticker        ADHI     ADMF  ...   WSKT    WTON   YELO   YPAS     YULE  ZATA  \
# Date                         ...
# 2022-09-22  732.52  6725.14  ...  530.0  228.94  101.0  790.0  2053.85   NaN
# 2022-09-23  732.52  6784.83  ...  525.0  228.94  104.0  985.0  2113.67   NaN
# 2022-09-26  700.47  6764.94  ...  515.0  213.68   99.0  920.0  2043.88   NaN
# 2022-09-27  695.90  6764.94  ...  515.0  213.68   99.0  860.0  2113.67   NaN
# 2022-09-28  677.58  6625.66  ...  510.0  207.96   99.0  845.0  2103.70   NaN
# ...            ...      ...  ...    ...     ...    ...    ...      ...   ...
# 2025-09-16  284.00  8950.00  ...  202.0  106.00   66.0  354.0  2700.00  36.0
# 2025-09-17  294.00  9000.00  ...  202.0  108.00   70.0  354.0  2710.00  39.0
# 2025-09-18  292.00  8975.00  ...  202.0  105.00   65.0  354.0  2710.00  42.0
# 2025-09-19  286.00  8950.00  ...  202.0  105.00   65.0  354.0  2690.00  46.0
# 2025-09-22  282.00  8925.00  ...  202.0  103.00   70.0  354.0  2680.00  50.0
#
# Ticker       ZBRA  ZINC     ZONE    ZYRX
# Date
# 2022-09-22  550.0  71.0  1091.97  480.24
# 2022-09-23  550.0  71.0  1106.46  475.58
# 2022-09-26  545.0  70.0  1101.63  475.58
# 2022-09-27  550.0  71.0  1101.63  466.25
# 2022-09-28  545.0  70.0  1091.97  456.93
# ...           ...   ...      ...     ...
# 2025-09-16   50.0  39.0   760.00  149.00
# 2025-09-17   50.0  42.0   755.00  149.00
# 2025-09-18   50.0  46.0   755.00  145.00
# 2025-09-19   50.0  50.0   755.00  145.00
# 2025-09-22   50.0  45.0   755.00  147.00
#
# [716 rows x 822 columns]

# %%
data_5year = data_saham_emitem[data_saham_emitem.index >= tanggal_paling_lama5]
daftar_perusahaan_5thn = data_5year[data_5year.index.year == tanggal_paling_lama5.year].dropna(axis=1, how="all")
daftar_perusahaan_5thn = daftar_perusahaan_5thn.columns.to_list()
data_5year = data_5year[daftar_perusahaan_5thn]
data_5year
# Out:
# Ticker         AALI   ABBA     ABDA     ABMM     ACES   ACST     ADES    ADHI  \
# Date
# 2020-09-22  8588.42  39.73  6545.42   619.14  1235.20  200.0   1140.0  466.98
# 2020-09-23  8443.56  39.73  6545.42   619.14  1259.66  197.0   1120.0  462.40
# 2020-09-24  8071.05  39.73  6447.72   612.02  1174.05  184.0   1115.0  448.67
# 2020-09-25  8257.30  39.73  6447.72   608.46  1280.04  184.0   1140.0  457.83
# 2020-09-28  8133.13  39.73  6447.72   583.56  1300.43  195.0   1140.0  462.40
# ...             ...    ...      ...      ...      ...    ...      ...     ...
# 2025-09-16  7750.00  52.00  2970.00  2930.00   436.00  134.0  13125.0  284.00
# 2025-09-17  7900.00  57.00  2970.00  2900.00   446.00  141.0  13150.0  294.00
# 2025-09-18  8000.00  62.00  2970.00  2890.00   436.00  138.0  13075.0  292.00
# 2025-09-19  7850.00  62.00  2970.00  2890.00   432.00  136.0  13350.0  286.00
# 2025-09-22  7775.00  68.00  2970.00  2890.00   426.00  135.0  13300.0  282.00
#
# Ticker         ADMF   ADMG  ...  WOWS   WSBP   WSKT    WTON   YELO   YPAS  \
# Date                        ...
# 2020-09-22  4242.37  120.0  ...  57.0  145.0  525.0  220.85  20.42  366.0
# 2020-09-23  4242.37  117.0  ...  55.0  144.0  510.0  217.11  20.42  342.0
# 2020-09-24  4242.37  117.0  ...  52.0  138.0  490.0  215.23  20.42  322.0
# 2020-09-25  4242.37  116.0  ...  54.0  142.0  505.0  218.98  20.42  390.0
# 2020-09-28  4242.37  117.0  ...  60.0  140.0  515.0  213.36  20.42  364.0
# ...             ...    ...  ...   ...    ...    ...     ...    ...    ...
# 2025-09-16  8950.00  152.0  ...  97.0   32.0  202.0  106.00  66.00  354.0
# 2025-09-17  9000.00  147.0  ...  93.0   30.0  202.0  108.00  70.00  354.0
# 2025-09-18  8975.00  139.0  ...  88.0   29.0  202.0  105.00  65.00  354.0
# 2025-09-19  8950.00  138.0  ...  90.0   29.0  202.0  105.00  65.00  354.0
# 2025-09-22  8925.00  139.0  ...  91.0   31.0  202.0  103.00  70.00  354.0
#
# Ticker         YULE   ZBRA   ZINC    ZONE
# Date
# 2020-09-22   189.43  40.94  133.0  364.33
# 2020-09-23   189.43  40.94  132.0  362.42
# 2020-09-24   199.40  40.94  128.0  360.50
# 2020-09-25   199.40  40.94  129.0  358.58
# 2020-09-28   199.40  40.94  128.0  358.58
# ...             ...    ...    ...     ...
# 2025-09-16  2700.00  50.00   39.0  760.00
# 2025-09-17  2710.00  50.00   42.0  755.00
# 2025-09-18  2710.00  50.00   46.0  755.00
# 2025-09-19  2690.00  50.00   50.0  755.00
# 2025-09-22  2680.00  50.00   45.0  755.00
#
# [1203 rows x 709 columns]

# %%
data_5year_max = data_5year.max().to_frame(name="Max 5 Years")
data_3year_max = data_3year.max().to_frame(name="Max 3 Years")
data_1year_max = data_1year.max().to_frame(name="Max 1 Years")
saham_from_max = pd.concat([data_1year_max,data_3year_max,data_5year_max,harga_sekarang],axis=1)
saham_from_max
# Out:
#         Max 1 Years  Max 3 Years  Max 5 Years     Now
# Ticker
# AADI       10275.00          NaN          NaN  7075.0
# AALI        8000.00      8000.00     11338.42  7775.0
# ABBA          68.00       232.00       560.15    68.0
# ABDA        4060.00      6725.00      7717.81  2970.0
# ABMM        4348.58      4567.92      4567.92  2890.0
# ...             ...          ...          ...     ...
# MINE            NaN          NaN          NaN   555.0
# OBAT            NaN          NaN          NaN   456.0
# RATU            NaN          NaN          NaN  6350.0
# YOII            NaN          NaN          NaN    98.0
# YUPI            NaN          NaN          NaN  1610.0
#
# [955 rows x 4 columns]

# %%
def check_status_max(row):
    now = row["Now"]
    max_5 = row["Max 5 Years"]
    max_3 = row["Max 3 Years"]
    max_1 = row["Max 1 Years"]

    if pd.notna(max_5) and now < max_5:
        return "Lowest than 5 years"
    elif pd.notna(max_3) and now < max_3:
        return "Lowest than 3 years"
    elif pd.notna(max_1) and now < max_1:
        return "Lowest than 1 years"
    else:
        return None

# %%
saham_from_max["Status"] = saham_from_max.apply(check_status_max, axis=1)
status_stock = saham_from_max["Status"].dropna()
status_stock
# Out:
# Ticker
# AADI    Lowest than 1 years
# AALI    Lowest than 5 years
# ABBA    Lowest than 5 years
# ABDA    Lowest than 5 years
# ABMM    Lowest than 5 years
#                ...
# ZATA    Lowest than 3 years
# ZBRA    Lowest than 5 years
# ZINC    Lowest than 5 years
# ZONE    Lowest than 5 years
# ZYRX    Lowest than 3 years
# Name: Status, Length: 847, dtype: object

# %%
data_5year_min = data_5year.min().to_frame(name="Min 5 Years")
data_3year_min = data_3year.min().to_frame(name="Min 3 Years")
data_1year_min = data_1year.min().to_frame(name="Min 1 Years")
saham_from_min = pd.concat([data_1year_min,data_3year_min,data_5year_min,harga_sekarang],axis=1)
saham_from_min
# Out:
#         Min 1 Years  Min 3 Years  Min 5 Years     Now
# Ticker
# AADI        5750.00          NaN          NaN  7075.0
# AALI        5065.43      5065.43      5065.43  7775.0
# ABBA          16.00        16.00        16.00    68.0
# ABDA        2970.00      2970.00      2970.00  2970.0
# ABMM        2698.79      2014.26       498.16  2890.0
# ...             ...          ...          ...     ...
# MINE            NaN          NaN          NaN   555.0
# OBAT            NaN          NaN          NaN   456.0
# RATU            NaN          NaN          NaN  6350.0
# YOII            NaN          NaN          NaN    98.0
# YUPI            NaN          NaN          NaN  1610.0
#
# [955 rows x 4 columns]

# %%
def check_status_min(row):
    now = row["Now"]
    min_5 = row["Min 5 Years"]
    min_3 = row["Min 3 Years"]
    min_1 = row["Min 1 Years"]

    if pd.notna(min_5) and now < min_5:
        return "Lowest than 5 years"
    elif pd.notna(min_3) and now < min_3:
        return "Lowest than 3 years"
    elif pd.notna(min_1) and now < min_1:
        return "Lowest than 1 years"
    else:
        return None

# %%
saham_from_min["Status"] = saham_from_min.apply(check_status_min, axis=1)
status_stock_min = saham_from_min["Status"].dropna()
status_stock_min
# Out:
# Series([], Name: Status, dtype: object)
